# %% [markdown]
# <a href="https://colab.research.google.com/github/SANGRAMLEMBE/100_days_of_ML/blob/main/Day_16_working_with_json_sql/Day_16_working_with_json_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # working with Json

# %%
pd.read_json('train.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-34ec4192ec3b> in <cell line: 0>()
# ----> 1 pd.read_json('train.json')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
# ...

# %%
pd.read_json('https://www.floatrates.com/daily/usd.json')
# Out:
#                                        aud                            cad  \
# code                                   AUD                            CAD
# alphaCode                              AUD                            CAD
# numericCode                            036                            124
# name                     Australian Dollar                Canadian Dollar
# rate                              1.560242                       1.385589
# date         Tue, 29 Apr 2025 15:55:13 GMT  Tue, 29 Apr 2025 15:55:13 GMT
# inverseRate                       0.640926                       0.721715
#
#                                        chf                            cny  \
# code                                   CHF                            CNY
# alphaCode                              CHF                            CNY
# numericCode                            756                            156
# name                           Swiss Franc                   Chinese Yuan
# ...

# %% [markdown]
# # working with SQL

# %%
# !pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.6 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
import pymysql

conn = pymysql.connect(
    host='localhost',
    user='root',
    password='Sangram@27',
    database='world'
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pymysql/connections.py in connect(self, sock)
#     648                         try:
# --> 649                             sock = socket.create_connection(
#     650                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# /usr/lib/python3.11/socket.py in create_connection(address, timeout, source_address, all_errors)
#     862             if not all_errors:
# --> 863                 raise exceptions[0]
#     864             raise ExceptionGroup("create_connection failed", exceptions)
#
# /usr/lib/python3.11/socket.py in create_connection(address, timeout, source_address, all_errors)
#     847                 sock.bind(source_address)
# --> 848             sock.connect(sa)
#     849             # Break explicitly a reference cycle
#
# ...

# %%
pd.read_sql_query('select * from city WHERE Countrycode LIKE 'IND'',conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-68ac09c6fa65> in <cell line: 0>()
# ----> 1 pd.read_sql_query('select * from city',conn)
#
# NameError: name 'pd' is not defined

# %%
pd.read_sql_query("select * from country WHERE LifeExpectancy >60",conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7b8ea5a7e568> in <cell line: 0>()
# ----> 1 pd.read_sql_query('select * from country',conn)
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_sql_query("select * from countrylanguage",conn)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8109501b9c9c> in <cell line: 0>()
# ----> 1 df = pd.read_sql_query("select * from countrylanguage",conn)
#       2 df
#
# NameError: name 'pd' is not defined
