# %%
import pandas as pd

# %% [markdown]
# # working with Json

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://www.floatrates.com/daily/usd.json')
# Out:
#                                       aud                           cad  \
# code                                  AUD                           CAD
# alphaCode                             AUD                           CAD
# numericCode                           036                           124
# name                    Australian Dollar               Canadian Dollar
# rate                             1.512517                      1.396178
# date         Thu, 4 Dec 2025 21:55:11 GMT  Thu, 4 Dec 2025 21:55:11 GMT
# inverseRate                       0.66115                      0.716241
#
#                                       chf                           cny  \
# code                                  CHF                           CNY
# alphaCode                             CHF                           CNY
# numericCode                           756                           156
# name                          Swiss Franc                  Chinese Yuan
# rate                             0.800726                       7.07089
# date         Thu, 4 Dec 2025 21:55:11 GMT  Thu, 4 Dec 2025 21:55:11 GMT
# inverseRate                      1.248866                      0.141425
#
#                                       eur                           gbp  \
# code                                  EUR                           GBP
# alphaCode                             EUR                           GBP
# numericCode                           978                           826
# name                                 Euro           U.K. Pound Sterling
# rate                             0.857223                      0.749499
# date         Thu, 4 Dec 2025 21:55:11 GMT  Thu, 4 Dec 2025 21:55:11 GMT
# inverseRate                      1.166558                      1.334225
#
#                                       hkd                           idr  \
# code                                  HKD                           IDR
# alphaCode                             HKD                           IDR
# numericCode                           344                           360
# name                     Hong Kong Dollar             Indonesian Rupiah
# rate                             7.782683                  16640.420852
# date         Thu, 4 Dec 2025 21:55:11 GMT  Thu, 4 Dec 2025 21:55:11 GMT
# inverseRate                       0.12849                       0.00006
#
#                                       inr                           jpy  ...  \
# code                                  INR                           JPY  ...
# alphaCode                             INR                           JPY  ...
# numericCode                           356                           392  ...
# name                         Indian Rupee                  Japanese Yen  ...
# rate                              90.0001                    154.965392  ...
# date         Thu, 4 Dec 2025 21:55:11 GMT  Thu, 4 Dec 2025 21:55:11 GMT  ...
# inverseRate                      0.011111                      0.006453  ...
#
#                                       vuv                           wst  \
# code                                  VUV                           WST
# alphaCode                             VUV                           WST
# numericCode                           548                           882
# name                         Vanuatu vatu                   Samoan tala
# rate                           121.138351                      2.777902
# date         Thu, 4 Dec 2025 21:55:11 GMT  Thu, 4 Dec 2025 21:55:11 GMT
# inverseRate                      0.008255                      0.359984
#
#                                       xcd                           xcg  \
# code                                  XCD                           XCG
# alphaCode                             XCD                           XCG
# numericCode                           951                           532
# name                East Caribbean Dollar             Caribbean guilder
# rate                             2.699983                      1.789988
# date         Thu, 4 Dec 2025 21:55:11 GMT  Thu, 4 Dec 2025 21:55:11 GMT
# inverseRate                      0.370373                      0.558663
#
#                                       xpf                           yer  \
# code                                  XPF                           YER
# alphaCode                             XPF                           YER
# numericCode                           953                           886
# name                            CFP Franc                   Yemeni rial
# rate                           102.290159                    238.367907
# date         Thu, 4 Dec 2025 21:55:11 GMT  Thu, 4 Dec 2025 21:55:11 GMT
# inverseRate                      0.009776                      0.004195
#
#                                       zmw                           irr  \
# code                                  ZMW                           IRR
# alphaCode                             ZMW                           IRR
# numericCode                           967                           364
# name                       Zambian kwacha                  Iranian rial
# rate                             23.06729                  42247.674419
# date         Thu, 4 Dec 2025 21:55:11 GMT  Thu, 4 Dec 2025 21:55:11 GMT
# inverseRate                      0.043351                      0.000024
#
#                                       lak                           syp
# code                                  LAK                           SYP
# alphaCode                             LAK                           SYP
# numericCode                           418                           760
# name                              Lao kip                  Syrian pound
# rate                         21756.287425                  11043.465046
# date         Thu, 4 Dec 2025 21:55:11 GMT  Thu, 4 Dec 2025 21:55:11 GMT
# inverseRate                      0.000046                      0.000091
#
# [7 rows x 146 columns]

# %% [markdown]
# # working with SQL

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\sangr\anaconda3\lib\site-packages (9.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost', user='root', password='', database='world'
)

# %%
pd.read_sql_query("SELECT * FROM city",conn)
# Out:
# C:\Users\sangr\AppData\Local\Temp\ipykernel_14728\2215102799.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city",conn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND'",conn)
# Out:
# C:\Users\sangr\AppData\Local\Temp\ipykernel_14728\2335966076.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND'",conn)
#        ID                Name CountryCode        District  Population
# 0    1024     Mumbai (Bombay)         IND     Maharashtra    10500000
# 1    1025               Delhi         IND           Delhi     7206704
# 2    1026  Calcutta [Kolkata]         IND    West Bengali     4399819
# 3    1027    Chennai (Madras)         IND      Tamil Nadu     3841396
# 4    1028           Hyderabad         IND  Andhra Pradesh     2964638
# ..    ...                 ...         ...             ...         ...
# 336  1360        Ambala Sadar         IND         Haryana       90712
# 337  1361          Baidyabati         IND    West Bengali       90601
# 338  1362               Morvi         IND         Gujarat       90357
# 339  1363             Raigarh         IND     Chhatisgarh       89166
# 340  1364            Vejalpur         IND         Gujarat       89053
#
# [341 rows x 5 columns]

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'USA'",conn)
# Out:
# C:\Users\sangr\AppData\Local\Temp\ipykernel_14728\3992278021.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'USA'",conn)
#        ID          Name CountryCode        District  Population
# 0    3793      New York         USA        New York     8008278
# 1    3794   Los Angeles         USA      California     3694820
# 2    3795       Chicago         USA        Illinois     2896016
# 3    3796       Houston         USA           Texas     1953631
# 4    3797  Philadelphia         USA    Pennsylvania     1517550
# ..    ...           ...         ...             ...         ...
# 269  4062       Kenosha         USA       Wisconsin       89447
# 270  4063         Elgin         USA        Illinois       89408
# 271  4064        Odessa         USA           Texas       89293
# 272  4065        Carson         USA      California       89089
# 273  4066    Charleston         USA  South Carolina       89063
#
# [274 rows x 5 columns]

# %%
pd.read_sql_query("SELECT * FROM city WHERE Population > 100000",conn)
# Out:
# C:\Users\sangr\AppData\Local\Temp\ipykernel_14728\2219331164.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE Population > 100000",conn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 3553  4074            Gaza         PSE           Gaza      353632
# 3554  4075      Khan Yunis         PSE     Khan Yunis      123175
# 3555  4076          Hebron         PSE         Hebron      119401
# 3556  4077        Jabaliya         PSE     North Gaza      113901
# 3557  4078          Nablus         PSE         Nablus      100231
#
# [3558 rows x 5 columns]

# %%
pd.read_sql_query("SELECT * FROM city WHERE Population < 50000",conn)
# Out:
# C:\Users\sangr\AppData\Local\Temp\ipykernel_14728\2746997638.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE Population < 50000",conn)
#       ID                Name CountryCode          District  Population
# 0     33          Willemstad         ANT           Curaçao        2345
# 1     53              Tafuna         ASM           Tutuila        5200
# 2     54            Fagatogo         ASM           Tutuila        2323
# 3     55    Andorra la Vella         AND  Andorra la Vella       21189
# 4     61          South Hill         AIA                 –         961
# ..   ...                 ...         ...               ...         ...
# 73  3424            Funafuti         TUV          Funafuti        4600
# 74  3536            Mata-Utu         WLF            Wallis        1137
# 75  3537           Port-Vila         VUT             Shefa       33700
# 76  3538  Città del Vaticano         VAT                 –         455
# 77  4067    Charlotte Amalie         VIR         St Thomas       13000
#
# [78 rows x 5 columns]

# %%
# here we storing our SQL data TAble into variable
df  = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
# Out:
# C:\Users\sangr\AppData\Local\Temp\ipykernel_14728\2911018930.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df  = pd.read_sql_query("SELECT * FROM countrylanguage",conn)

# %%
df
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]
