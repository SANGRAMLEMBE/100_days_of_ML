# %% [markdown]
# <a href="https://colab.research.google.com/github/SANGRAMLEMBE/100_days_of_ML/blob/main/Day_16_working_with_json_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # working with Json

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://www.floatrates.com/daily/usd.json')
# Out:
#                                        aud                            cad  \
# code                                   AUD                            CAD
# alphaCode                              AUD                            CAD
# numericCode                            036                            124
# name                     Australian Dollar                Canadian Dollar
# rate                              1.561529                       1.385972
# date         Mon, 28 Apr 2025 23:59:00 GMT  Mon, 28 Apr 2025 23:59:00 GMT
# inverseRate                       0.640398                       0.721515
#
#                                        chf                            cny  \
# code                                   CHF                            CNY
# alphaCode                              CHF                            CNY
# numericCode                            756                            156
# name                           Swiss Franc                   Chinese Yuan
# ...

# %% [markdown]
# # working with SQL

# %%
 # !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 60.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp311-cp311-linux_x86_64.whl size=247951 sha256=69d6e2f7bbadbab3fb0e996d45de68ce4975c502b61e9e3ec989a9df369c9414
#   Stored in directory: /root/.cache/pip/wheels/17/cd/ed/2d49e9bac69cf09382e4c7cc20a2511202b48324b87db26019
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

# %%
mysql.connector.connect(
    host='localhost',user='root',password='',database='world')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/mysql/connector/network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-15-10c16e9d0cce> in <cell line: 0>()
# ----> 1 mysql.connector.connect(
#       2     host='localhost',user='root',password='',database='world')
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# ...

# %%
import mysql.connector
cnx = mysql.connector.connect(
    host='LOCALHOST',  # Connect through the proxy
    user='ROOT',
    password='',
    database='WORLD'
)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/mysql/connector/network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-16-2fc7aedbb145> in <cell line: 0>()
#       1 import mysql.connector
# ----> 2 cnx = mysql.connector.connect(
#       3     host='LOCALHOST',  # Connect through the proxy
#       4     user='ROOT',
#       5     password='',
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
# ...
