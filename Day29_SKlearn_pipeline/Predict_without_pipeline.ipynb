# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('models/ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('models/ohe_embarked.pkl','rb'))
clf = pickle.load(open('models/clf.pkl','rb'))



# we have to keep name same as in other file (Titanic_without_pipeline)
# so it will behave same as like that

# %%
# Assume user input

# pclass/gender/age/Sibsp/Parch/Fare/Embarked

#test_input = np.array([2,'male',22.0,	1,	0,	7.2500, 'S'])
test_input = np.array([2,'male',32.0,	0,	0,	10.5, 'S'])

# %%
test_input

# Turns a 1D array of shape (n,) into a 2D array of shape (1, n)
test_input = test_input.reshape(1, -1)

# %%
import pandas as pd

sex_df = pd.DataFrame([['male']], columns = ['Sex'])
test_input_sex = ohe_sex.transform(sex_df)

# %%
test_input_sex # for male --> 0, 1   # for Female --> 1,0
# Out:
# array([[0., 1.]])

# %%
Emb_df = pd.DataFrame([['S']], columns = ['Embarked'])

test_input_embarked = ohe_embarked.transform(Emb_df)
# Out:
# C:\Users\sangr\anaconda3\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(

# %%
test_input_embarked
# Out:
# array([[0., 0., 1.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
for arr in [test_input[:,[0,3,4,5]], test_input_age, test_input_sex, test_input_embarked]:
    print(arr.shape)
# Out:
# (1, 4)
# (1, 1)
# (1, 2)
# (1, 3)

# %%
# Now your original line should work:
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]], test_input_age, test_input_sex, test_input_embarked), axis=1)
